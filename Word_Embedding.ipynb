# %%
# Tensorflow > 2.0 and Tensorflow < 2.0
"""
tf > 2.0 --> keras integrated with tf
tf < 2.0 --> import both libararies individually
"""
# Out:
# '\ntf > 2.0 --> keras integrated with tf\ntf < 2.0 --> import both libararies individually\n'

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    'the glass of milk',
    'the glass of juice',
    'I am a good student',
    'I am a good developer',
    'understand the meaning of words',
    'your work is good',
]

# %%
##vocab libarry
vocb_size = 10000

# %%
onehot_rep = [one_hot(words,vocb_size) for words in sent]

# %%
onehot_rep
# Out:
# [[3546, 4874, 7493, 5712],
#  [3546, 4874, 7493, 9744],
#  [8889, 7682, 9689, 9821, 6078],
#  [8889, 7682, 9689, 9821, 6166],
#  [2116, 3546, 5115, 7493, 9651],
#  [4436, 1819, 9348, 9821]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(onehot_rep, padding='pre',maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 3546, 4874, 7493, 5712],
#        [   0,    0,    0,    0, 3546, 4874, 7493, 9744],
#        [   0,    0,    0, 8889, 7682, 9689, 9821, 6078],
#        [   0,    0,    0, 8889, 7682, 9689, 9821, 6166],
#        [   0,    0,    0, 2116, 3546, 5115, 7493, 9651],
#        [   0,    0,    0,    0, 4436, 1819, 9348, 9821]])

# %%
dim = 15

# %%
model = Sequential()
model.add(Embedding(vocb_size,10,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 8, 10)             100000
# ...
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(embedded_docs))
# Out:
# [[[-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664
#    -0.02403336 -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#   [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664
#    -0.02403336 -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#   [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664
#    -0.02403336 -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#   [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664
#    -0.02403336 -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#   [-0.02715102  0.04915675  0.00123253 -0.00828452 -0.00022644
#     0.02476576 -0.04933223 -0.02503099 -0.03657609 -0.03484083]
#   [-0.03564627  0.00416493  0.03492436  0.00623038 -0.04143614
#    -0.00524928  0.03050533 -0.01381804 -0.04407885 -0.01548918]
#   [-0.00038702 -0.00889075 -0.00258163 -0.01523228  0.00178566
#    -0.03075377 -0.007987    0.01816869  0.02207505  0.04738493]
#   [-0.04046601  0.01331285 -0.01382761  0.04947172 -0.02679269
# ...

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3546, 4874, 7493, 5712])

# %%
print(model.predict(embedded_docs)[0])
# Out:
# [[-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664  -0.02403336
#   -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#  [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664  -0.02403336
#   -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#  [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664  -0.02403336
#   -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#  [-0.01091029 -0.0159749  -0.01025928  0.04817355  0.0336664  -0.02403336
#   -0.01023684 -0.00460055 -0.02639647 -0.04715966]
#  [-0.02715102  0.04915675  0.00123253 -0.00828452 -0.00022644  0.02476576
#   -0.04933223 -0.02503099 -0.03657609 -0.03484083]
#  [-0.03564627  0.00416493  0.03492436  0.00623038 -0.04143614 -0.00524928
#    0.03050533 -0.01381804 -0.04407885 -0.01548918]
#  [-0.00038702 -0.00889075 -0.00258163 -0.01523228  0.00178566 -0.03075377
#   -0.007987    0.01816869  0.02207505  0.04738493]
#  [-0.04046601  0.01331285 -0.01382761  0.04947172 -0.02679269  0.04265836
# ...
